# %%
import numpy as np
import matplotlib.pyplot as plt
blinks = np.load('./drowsiness_stable/Blinks_30_1.npy')
print(blinks.shape)
# Out:
# (1091, 30, 4)

# %%
blinksTest = np.load('./drowsiness_stable/BlinksTest_30_1.npy')
print(blinksTest)
# Out:
# [[[ 1.35419868e+01  1.66991634e+00 -5.44137020e-02  1.27436004e+00]
#   [ 2.84375199e+01  5.89126215e-01 -5.44137020e-02 -1.89031043e-01]
#   [ 1.68814160e+01  1.42416211e+00 -2.59976576e-01  2.08515781e+00]
#   ...
#   [ 2.69633606e+00  1.37659677e+00 -5.44137020e-02  1.15570671e+00]
#   [ 1.45299909e-01  1.41359203e+00 -2.59976576e-01  9.57951160e-01]
#   [ 4.48066832e-01  1.35281410e+00  1.51149172e-01  6.01991166e-01]]
#
#  [[ 1.68814160e+01  1.42416211e+00 -2.59976576e-01  2.08515781e+00]
#   [ 2.31795676e+01  6.84256887e-01 -4.65539451e-01  1.29413560e+00]
#   [ 2.83116168e+01 -3.83320646e-01 -4.65539451e-01  1.07602286e-01]
#   ...
#   [ 4.48066832e-01  1.35281410e+00  1.51149172e-01  6.01991166e-01]
#   [ 5.40995293e-01  1.35017159e+00  1.51149172e-01  5.42664501e-01]
#   [-1.00281624e+00  8.00527707e-01  3.56712047e-01 -1.73152435e+00]]
#
#  [[ 2.83116168e+01 -3.83320646e-01 -4.65539451e-01  1.07602286e-01]
# ...

# %%
a.shape[0]
# Out:
# 1091

# %%
print("BLINK DURATION")
a = blinks[:,:,0]
new_a = np.reshape(a,a.shape[0]*a.shape[1])
print(new_a.shape)
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(new_a, bins = 200)
print(min(new_a), max(new_a))
# Show plot
plt.show()
# Out:
# BLINK DURATION
# (32730,)
# -35.227454409837414 426.41599528226806

# %%
print("BLINK AMPLITUDE")
a = blinks[:,:,1]
new_a = np.reshape(a,a.shape[0]*a.shape[1])
print(new_a.shape)
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(new_a, bins = 200)
print(min(new_a), max(new_a))
# Show plot
plt.show()
# Out:
# BLINK AMPLITUDE
# (32730,)
# -3.9770183901979337 4.335478934747612

# %%
print("EYE OPENING VELOCITY")
a = blinks[:,:,2]
new_a = np.reshape(a,a.shape[0]*a.shape[1])
print(new_a.shape)
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(new_a, bins = 200)
print(min(new_a), max(new_a))
# Show plot
plt.show()
# Out:
# EYE OPENING VELOCITY
# (32730,)
# -4.703841439137399 64.76717847809246

# %%
print("FREQUENCY")
a = blinks[:,:,3]
new_a = np.reshape(a,a.shape[0]*a.shape[1])
print(new_a.shape)
# Creating histogram
fig, ax = plt.subplots(figsize =(10, 7))
ax.hist(new_a, bins = 200)
print(min(new_a), max(new_a))
# Show plot
plt.show()
# Out:
# FREQUENCY
# (32730,)
# -4.880224230066022 9.516749289847548

# %%
blinks[1]
# Out:
# array([[ 1.36507483e+02, -1.29510487e+00, -8.56819102e-01,
#         -6.24851860e-01],
#        [ 1.37472828e+02, -2.33872761e+00, -2.18964882e+00,
#          5.90137868e-01],
#        [ 1.39987807e+02, -2.02367169e+00, -1.74537224e+00,
#          1.85141292e-01],
#        [ 1.41816883e+02, -9.32790563e-01, -4.12542530e-01,
#          1.52162999e+00],
#        [ 1.39454327e+02, -5.62599857e-01, -8.56819102e-01,
#          1.04141977e-01],
#        [ 1.39200289e+02, -1.57077880e+00, -8.56819102e-01,
#         -1.35384570e+00],
#        [ 1.35313503e+02, -2.82706428e+00, -4.12542530e-01,
#          1.27863205e+00],
#        [ 1.32265043e+02, -1.07062753e+00, -4.12542530e-01,
#         -1.07034809e+00],
#        [ 1.29470622e+02, -1.02336914e+00, -8.56819102e-01,
#         -9.89348779e-01],
#        [ 1.28886334e+02,  2.88051127e-01, -4.12542530e-01,
#          8.73635471e-01],
#        [ 1.27743161e+02, -8.69779379e-01, -4.12542530e-01,
#         -1.23234672e+00],
# ...
